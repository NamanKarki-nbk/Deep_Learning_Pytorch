# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import DataLoader, Dataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from collections import Counter
import re
import spacy
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/mdismielhossenabir/sentiment-analysis")
# Out:
# Skipping, found downloaded files in "./sentiment-analysis" (use force=True to force download)

# %%
data = pd.read_csv('sentiment-analysis/sentiment_analysis.csv')

# %%
data.head()
# Out:
#    Year  Month  Day Time of Tweet  \
# 0  2018      8   18       morning
# 1  2018      8   18          noon
# 2  2017      8   18         night
# 3  2022      6    8       morning
# 4  2022      6    8          noon
#
#                                                 text sentiment     Platform
# 0              What a great day!!! Looks like dream.  positive    Twitter
# 1     I feel sorry, I miss you here in the sea beach  positive    Facebook
# 2                                     Don't angry me  negative     Facebook
# 3  We attend in the class just for listening teac...  negative    Facebook
# 4                  Those who want to go, let them go  negative   Instagram

# %%
df = data[['text', 'sentiment']]

# %%
data_lowercase = df.copy()
data_lowercase=data_lowercase[['text', 'sentiment']].apply(lambda x: x.str.lower())
print(data_lowercase.head())
# Out:
#                                                 text sentiment
# 0              what a great day!!! looks like dream.  positive
# 1     i feel sorry, i miss you here in the sea beach  positive
# 2                                     don't angry me  negative
# 3  we attend in the class just for listening teac...  negative
# 4                  those who want to go, let them go  negative

# %%
def clean_data(text):
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'@\w+', '', text)     # Remove mentions
    text = re.sub(r'#\w+', '', text)     # Remove hashtags
    text = re.sub(r'[^A-Za-z\s]', '', text)  # Remove special characters and numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# %%
data_lowercase['text'] = data_lowercase['text'].apply(clean_data)
print(data_lowercase.head())
# Out:
#                                                 text sentiment
# 0                  what a great day looks like dream  positive
# 1      i feel sorry i miss you here in the sea beach  positive
# 2                                      dont angry me  negative
# 3  we attend in the class just for listening teac...  negative
# 4                   those who want to go let them go  negative

# %%
#creating vocabulary 
nlp = spacy.load("en_core_web_sm")

def tokenize(text):
    return [token.text for token in nlp(text)]


text_tokens = (data_lowercase['text'].apply(tokenize)).to_list()
sentiment_tokens = (data_lowercase['sentiment'].apply(tokenize)).to_list()
all_text = [token for tokens in text_tokens for token in tokens]
all_sentiments = [token for tokens in sentiment_tokens for token in tokens]

# %%
word_counts = Counter(all_text)
sentiment_counts = Counter(all_sentiments)

word2idx = {"<PAD>": 0, "<UNK>": 1}
sentiment2idx = {"<PAD>": 0, "<UNK>": 1}
min_freq = 1
idx = len(word2idx)
for word, count in word_counts.items():
    if count >= min_freq:
        word2idx[word] = idx 
        idx += 1
   
for sentiment, count in sentiment_counts.items():
    if count >= min_freq:
        sentiment2idx[sentiment] = idx 
        idx += 1

idx2word = {idx: word for word, idx in word2idx.items()} 
idx2sentiment = {idx: sentiment for sentiment, idx in sentiment2idx.items()}

# %%
print(word2idx)
print(sentiment2idx)
print(idx2word)
print(idx2sentiment)
vocab_size = len(word2idx)
sentiment_size = len(sentiment2idx)
print(f"Vocabulary Size: {vocab_size}")
print(f"Sentiment Size: {sentiment_size}")
# Out:
# {'<PAD>': 0, '<UNK>': 1, 'what': 2, 'a': 3, 'great': 4, 'day': 5, 'looks': 6, 'like': 7, 'dream': 8, 'i': 9, 'feel': 10, 'sorry': 11, 'miss': 12, 'you': 13, 'here': 14, 'in': 15, 'the': 16, 'sea': 17, 'beach': 18, 'do': 19, 'nt': 20, 'angry': 21, 'me': 22, 'we': 23, 'attend': 24, 'class': 25, 'just': 26, 'for': 27, 'listening': 28, 'teachers': 29, 'reading': 30, 'on': 31, 'slide': 32, 'nonsence': 33, 'those': 34, 'who': 35, 'want': 36, 'to': 37, 'go': 38, 'let': 39, 'them': 40, 'its': 41, 'night': 42, 'am': 43, 'feeling': 44, 'neutral': 45, 'fe
they': 236, 're': 237, 'going': 238, 'write': 239, 'off': 240, 'crossing': 241, 'fingers': 242, 'waiting': 243, 'yor': 244, 'unromantic': 245, 'mayday': 246, 'd': 247, 'rather': 248, 'early': 249, 'runbut': 250, 'morning': 251, 'runner': 252, 'only': 253, 'available': 254, 'pm': 255, 'dear': 256, 'girl': 257, 'hair': 258, 'salon': 259, 'asked': 260, 'shall': 261, 'trim': 262, 'your': 263, 'eyebrows': 264, 'old': 265, 'talk': 266, 'soo': 267, 'bored': 268, 'video': 269, 'concert': 270, 'had': 271, 'nicotine': 272, 'replacement': 273, 'patch': 274, 'hours': 275, 'far': 276, 'did': 277, 'most': 278, 'getting': 279, 'bit': 280, 'twitchy': 281, 'raining': 282, 'need': 283, 'an': 284, 'umbrella': 285, 'should': 286, 'be': 287, 'sleeping': 288, 'couple': 289, 'ago': 290, 'depressed': 291, 'thinking': 292, 'suicide': 293, 'heard': 294, 'saw': 295, 'nightmare': 296, 'yesterday ...
# {'<PAD>': 0, '<UNK>': 1, 'positive': 1377, 'negative': 1378, 'neutral': 1379}
# {0: '<PAD>', 1: '<UNK>', 2: 'what', 3: 'a', 4: 'great', 5: 'day', 6: 'looks', 7: 'like', 8: 'dream', 9: 'i', 10: 'feel', 11: 'sorry', 12: 'miss', 13: 'you', 14: 'here', 15: 'in', 16: 'the', 17: 'sea', 18: 'beach', 19: 'do', 20: 'nt', 21: 'angry', 22: 'me', 23: 'we', 24: 'attend', 25: 'class', 26: 'just', 27: 'for', 28: 'listening', 29: 'teachers', 30: 'reading', 31: 'on', 32: 'slide', 33: 'nonsence', 34: 'those', 35: 'who', 36: 'want', 37: 'to', 38: 'go', 39: 'let', 40: 'them', 41: 'its', 42: 'night', 43: 'am', 44: 'feeling', 45: 'neutral', 46: 'feedings', 47: 'baby', 48: 'are', 49: 'fun', 50: 'when', 51: 'he', 52: 'is', 53: 'all', 54: 'smiles', 55: 'and', 56: 'coos', 57: 'soooo', 58: 'high', 59: 'both', 60: 'of', 61: 'today', 62: 'first', 63: 'time', 64: 'arrive', 65: 'boat', 66: 'amazing', 67: 'journey', 68: 'love', 69: 'something', 70: 'emc', 71: 'rules', 72: 'really', 73: 'song', 74: 'cardigan', 75: 'by', 76: 'taylor', 77: 'swift', 78: 'my', 79: 'sharpie', 80: 'running', 81: 'dangerously', 82: 'low', 83: 'ink', 84: 'music', 85: 'tonight', 86: 'but', 87: 'lost', 88: 'voice', 89: 'always', 90: 'somewhere', 91: 'where', 92: 'have', 93: 'been', 94: 'distrube', 95: 'care', 96: 'can', 97: 've', 98: 'sick', 99: 'past', 100: 'few', 101: 'days', 102: 'm', 103: 'come', 104: 'back', 105: 'home', 106: 'job', 107: 'good', 108: 'will', 109: 'never', 110: 'fall', 111: 'until', 112: 'found', 113: 'oh', 114: 'maya', 115: 'so', 116: 'hope', 117: 'find', 118: 'her', 119: 'soon', 120: 'playing', 121: 'with', 122: 'kids', 123: 'cleaning', 124: 'house', 125: 'family', 126: 'comming', 127: 'later', 128: 'tried', 129: 'shtdown', 130: 'pc', 131: 'accenditenly', 132: 'click', 133: 'restart', 134: 'button', 135: 'disgusting', 136: 'follow', 137: 'too', 138: 'game', 139: 'everyday', 140: 'village', 141: 'now', 142: 'there', 143: 'hardly', 144: 'internate', 145: 'gloomy', 146: 'juss', 147: 'came', 148: 'from', 149: 'barisal', 150: 'went', 151: 'sleep', 152: 'power', 153: 'cut', 154: 'how', 155: 'our', 156: 'company', 157: 'new', 158: 'logo', 159: 'buy', 160: 'sophies', 161: 'world', 162: 'book', 163: 'happy', 164: 'if', 165: 'it', 166: 'any', 167: 'consolation', 168: 'got', 169: 'bmi', 170: 'tested', 171: 'hahaha', 172: 'says', 173: 'obesed', 174: 'well', 175: 'much', 176: 'being', 177: 'unhappy', 178: 'about', 179: 'minutes', 180: 'that', 181: 's', 182: 'very', 183: 'funny', 184: 'cute', 185: 'ahhh', 186: 'slept', 187: 'through', 188: 'gon', 189: 'na', 190: 'try', 191: 'best', 192: 'watch', 193: 'tomorrow', 194: 'though', 195: 'play', 196: 'army', 197: 'semester', 198: 'final', 199: 'exam', 200: 'complete', 201: 'hurray', 202: 'born', 203: 'raised', 204: 'nyc', 205: 'living', 206: 'texas', 207: 'years', 208: 'still', 209: 'ny', 210: 'case', 211: 'wonder', 212: 'busy', 213: 'this', 214: 'coming', 215: 'adding', 216: 'tons', 217: 'blogs', 218: 'updates', 219: 'stay', 220: 'tuned', 221: 'soooooo', 222: 'sleeeeepy', 223: 'last', 224: 'o', 225: 'school', 226: 'was', 227: 'todaysniffle', 228: 'romance', 229: 'zero', 230: 'car', 231: 'not', 232: 'big', 233: 'dent', 234: 'boot', 235: 'hoping', 236: 'they', 237: 're', 238: 'going', 239: 'write', 240: 'off', 241: 'crossing', 242: 'fingers', 243: 'waiting', 244: 'yor', 245: 'unromantic', 246: 'mayday', 247: 'd', 248: 'rather', 249: 'early', 250: 'runbut', 251: 'morning', 252: 'runner', 253: 'only', 254: 'available', 255: 'pm', 256: 'dear', 257: 'girl', 258: 'hair', 259: 'salon', 260: 'asked', 261: 'shall', 262: 'trim', 263: 'your', 264: 'eyebrows', 265: 'old', 266: 'talk', 267: 'soo', 268: 'bored', 269: 'video', 270: 'concert', 271: 'had', 272: 'nicotine', 273: 'replacement', 274: 'patch', 275: 'hours', 276: 'far', 277: 'did', 278: 'most', 279: 'getting', 280: 'bit', 281: 'twitchy', 282: 'raining', 283: 'need', 284: 'an', 285: 'umbrella', 286: 'should', 287: 'be', 288: 'sleeping', 289: 'couple', 290: 'ago', 291: 'depressed', 292: 'thinking', 293: 'suicide', 294: 'heard', 295: 'saw', 296: 'nightmare', 297: 'yest ...
# {0: '<PAD>', 1: '<UNK>', 1377: 'positive', 1378: 'negative', 1379: 'neutral'}
# Vocabulary Size: 1377
# Sentiment Size: 5
